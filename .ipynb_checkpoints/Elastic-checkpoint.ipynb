# %%
from pprint import pprint
import re
import json
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
import sys
import codecs
from elasticsearch import Elasticsearch, ElasticsearchException, SerializationError,TransportError,\
ConnectionError, ConnectionTimeout, NotFoundError, RequestError
from elasticsearch.helpers import bulk, BulkIndexError, parallel_bulk
from bs4 import BeautifulSoup
from collections import deque
import pysftp
import os
from datetime import datetime
sys.path.append('/home/michaelp/REVIEWS')
import util
logfilename="log.txt"
logfile=open(logfilename, 'a')
logfile.write("established log file: "+datetime.now().isoformat()+"\n")
logfile.flush()
INDEX_NAME = "publication"  # the name of the index
DOC_TYPE = "html"  # we have a single type of document, so it doesn't matter
REMOVE_STOPWORDS=True
STEM=False
INDEX_SETTINGS = {  # two shards with a single replica
    "settings" : {
        "index" : {
            "number_of_shards" : 6,
            "number_of_replicas" : 1
           #,"similarity" : { "default" : { "type" : "LMJelinekMercer", "lambda":"0.4" }
            }
        }
        ,
    "mappings": {
            "html": {
            "properties": {
#                "post_date": { "type": "date" }
#                ,
                "title": {"type": "text" }
                ,
#                "id": { "type": "keyword"}
#                ,
                "text": { "type": "text" }
                ,
                "description": {"type": "text"}
                ,
                "keywords": {"type": "keyword"}
                ,
                "classification":{"type": "text"}
                }
            }
        }
    }

DCTR=0
DOCS_IN_FILE=0
es = Elasticsearch("localhost:9211", timeout=100)
if es.indices.exists(INDEX_NAME):
    print("index exists")
    #es.indices.delete(index=INDEX_NAME)
else:
    print("cannot")
    sys.exit()
#pprint (es.indices.stats(index="publication"))
body = {
	
    "size": 1000,           # get 100 docs (default = 10)
    "_source": ["work.subjects"], # get only wanted fields
	 "query": { 
         "query_string":{"query":"Oslo"}# the query
	 }
}
result=es.search(index="publication", body=body)
type(result)

pprint(es.search(index="publication", body=body))
# Out:
# full_url: http://localhost:9211/publication
# index exists
# full_url: http://localhost:9211/publication/_search
# full_url: http://localhost:9211/publication/_search
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9fa88bf03f89c56afe5c986157bb1852',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf579492e328e4f22ee845b6003015e7b',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {'work': {'subjects': ['Ligningsregistre',
#                                                       'Oslo',
#                                                       'Skatter og '
#                                                       'skattlegging']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpefa12493b8490d07e435a2a4ff88fe0e',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {'work': {'subjects': ['Ligningsregistre',
#                                                       'Oslo',
#                                                       'Skatter og '
#                                                       'skattlegging']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpa1efb4c01837c2d6f8ba9a0e4f2cc42d',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Ligningsregistre',
#                                                       'Skatter og '
#                                                       'skattlegging']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp02c88902814f86d87f55a4b55f939e8f',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {'work': {'subjects': ['Skatter og skattlegging',
#                                                       'Oslo',
#                                                       'Ligningsregistre']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp94d7cd7de2a10701237c07815b94a50d',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Ligningsregistre',
#                                                       'Skatter og '
#                                                       'skattlegging']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp6dd585c6a8ba448c23bb4922b1eea2d8',
#                     '_index': 'publication',
#                     '_score': 13.095567,
#                     '_source': {'work': {'subjects': ['Lover og forskrifter',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp63c439b5188f3370374c4645bfac4b8e',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8a2efa47cbb251b02bb6a411bdfab409',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp163f4140777563629c3fb03b4a3ef9ed',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4256c6ea034cbd25612e82807cf10928',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpc1e4b7f992b951282b90870ce71a7556',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp947529457080',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp045616254294',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpce8526198c80ef8abdf159527c089662',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpe9e58e9f4e30992447892ac5b61e0f79',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpadadc84c120ad4dc9c027f3df6cd38dd',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcdd7ede5cf016a38269f951c7fb8177f',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp2c3e0014e0d6f6327263d748976eb4e3',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp7183159d216a836afe8560a1472674fb',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp621d0d3016080a5206e3e57b13ef31f2',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8cd78087a93cd046032cad0b721da1a7',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp02484b6cb54b61c29f48987183e1a100',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp60772f90a64cb06541603580fab6ad40',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp00509a3fc68b69b36f7cc26590a38ddb',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp0a50ed5520709d5b855b29b0c2f15dcb',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpd331f09519135ae97c7de2fe64e6799e',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpc4bb03fe70789b9e2d9d560466528c4a',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp0f665888bbfd8aae30aa2aa41f95f9c1',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcf0435e06675b1472dd0c6e5daa1d65c',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpe32ce865f1b84d056dfcc32580571cf8',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp05bf2c629196b12149ef652bbabcf430',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3e1a95b4654c87df96c6c4cada39616f',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpc44ab9ce7478de927a5e20f01e122052',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9655395a9e456fb3e1a8bfe8d22911b8',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpd339ae823034847b47778fa64211514b',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp7d95674bbf5fd37d25d9a752f8a69d69',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp60c7fa31e074870a80180859d1c3e0f0',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4d1851d07edcfe326548a6d7894a1839',
#                     '_index': 'publication',
#                     '_score': 11.686511,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp260907366128',
#                     '_index': 'publication',
#                     '_score': 10.989177,
#                     '_source': {'work': {'subjects': ['Australia']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp334afdc52e3a7f215054603efd6c9a42',
#                     '_index': 'publication',
#                     '_score': 10.108978,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Befolkning',
#                                                       'Statistikk']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpffaadaf5dec2c337dac6cd9a7536122b',
#                     '_index': 'publication',
#                     '_score': 9.683842,
#                     '_source': {'work': {'subjects': ['Historie',
#                                                       'Dagligliv',
#                                                       'Fotografier',
#                                                       '1900-1999',
#                                                       'Oslo',
#                                                       'Geografi og reiser']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp860c9184bad0234e9165714366b123a4',
#                     '_index': 'publication',
#                     '_score': 9.594908,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2F1c89543b-cd5c-4f9a-9d55-7b8f5435615b',
#                     '_index': 'publication',
#                     '_score': 9.577426,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9e9852908ff0385eeea54ad9f434ff7c',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpc882024ee13cd91fe94adec4318b9b76',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp141adf32d37c8752bc0d1f8f285790c3',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Historie',
#                                                       '1900-1999']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp49703364705c8acd967bc5a6765f891a',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Kart', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp506704d82f9aa8a02438692035845c34',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp7e333ecf7b8daed1e3ea8f521353ca53',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Geografi og reiser']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpdf75df778ad15a2d8eca0444b258c198',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp2c8d53d3466b2b331ea606fd0985ac69',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Norge',
#                                                       'Oslo i litteratur',
#                                                       'Industri',
#                                                       'Oslo',
#                                                       'Dialekter',
#                                                       'Historie',
#                                                       'Norsk språk',
#                                                       'Litteratur']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp15c15707c2255879c0f6237447b7bc0c',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Historie',
#                                                       'Oslo',
#                                                       '1900-1999']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp27964fd8126c40a78f05f8c88992f540',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp354037850920',
#                     '_index': 'publication',
#                     '_score': 9.527978,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp6b79c3b5af18a736d44630bc156226a6',
#                     '_index': 'publication',
#                     '_score': 9.34451,
#                     '_source': {'work': {'subjects': ['Dagligliv',
#                                                       'Oslo',
#                                                       '1900-1999',
#                                                       'Historie']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp50deadfead918925536dcb8bc6fce747',
#                     '_index': 'publication',
#                     '_score': 9.274243,
#                     '_source': {'work': {'subjects': ['-800',
#                                                       'Oslo',
#                                                       'Norge',
#                                                       'Historie',
#                                                       'Fortidsminner',
#                                                       'Geologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp0a3fba2730ffcbdda1e6d7ab7a47e787',
#                     '_index': 'publication',
#                     '_score': 9.131188,
#                     '_source': {'work': {'subjects': ['Historie',
#                                                       'Skipsfart',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpfe0130eb63c8d57df7ab618f0031943c',
#                     '_index': 'publication',
#                     '_score': 9.131188,
#                     '_source': {'work': {'subjects': ['Kart (Atlas)',
#                                                       'Kart',
#                                                       'Oslo',
#                                                       'Bydelsinndeling',
#                                                       'Karter']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp19c56e40a632909b56b669d95547fdaa',
#                     '_index': 'publication',
#                     '_score': 9.131188,
#                     '_source': {'work': {'subjects': ['Kart', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9d4ba8e16d571f7fc48c997c27fd10d0',
#                     '_index': 'publication',
#                     '_score': 9.131188,
#                     '_source': {'work': {'subjects': ['Kart', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp824dc08b6062c6cdbe6c6b605558fa89',
#                     '_index': 'publication',
#                     '_score': 9.072429,
#                     '_source': {'work': {'subjects': ['Oslofjorden',
#                                                       'Oslomarka']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf0c26d6873b21248e172c4d093723326',
#                     '_index': 'publication',
#                     '_score': 8.900672,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcd28198825c7b15514b85396f1b0f7bf',
#                     '_index': 'publication',
#                     '_score': 8.874049,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Gassforsyning',
#                                                       'Oslo lysverker']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf2d2c85b53d279dbe27e649a41194496',
#                     '_index': 'publication',
#                     '_score': 8.791416,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp356008706bb92bf7d0d6d6f1edfdfda7',
#                     '_index': 'publication',
#                     '_score': 8.769135,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpd9a75ec73ba626edf68611f19095b665',
#                     '_index': 'publication',
#                     '_score': 8.769135,
#                     '_source': {'work': {'subjects': ['1960-tallet', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp19d518a1c75ba22377b5b0b830abbace',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo', 'Bysosiologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp96ce8b677c9beba7123d07e91a0e3d77',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Samferdsel',
#                                                       'Forvaltning',
#                                                       'Oslo',
#                                                       'Trafikkregulering']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp0f5d65a511cbd8358985294f69cd33bf',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Geografi og reiser']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp11df5698f3647a74fb2344eed3e1deb5',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpb334d40963c7a2f435f06d2c26c74e11',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp0c937c47333baaf451b0081e0392bc5b',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Wessel, Peter (fiktiv '
#                                                       'person)',
#                                                       '1990-tallet']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp44352fc35d10c0511065e8c010f4dbfa',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Nordmarka', 'Kart']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcbb4c3e7c515b7f40c4c5200fa9833ee',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Tidsskrifter',
#                                                       'Bysosiologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3a193b8003fed9b51b4aa278b1cc11f2',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Fotografier',
#                                                       'Geografi og reiser']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp442129324987',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp765982720212',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcbad641440c6b57c08a677d502710eea',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp960dfa73b430ea4dfced5a9c5077eecb',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['1990-tallet',
#                                                       'Wessel, Peter (fiktiv '
#                                                       'person)',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpabc657394a8e60e02838f27871dad20c',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf9de29866c5f474d0d4cbc46a5102df3',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart',
#                                                       'Oslo',
#                                                       'Kart (Atlas)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf9ec020c1b9f907b3eb0e8ed7b619cda',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart',
#                                                       'Oslo',
#                                                       'Kart (Atlas)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4c515f5b0bd0c6d209cf64bec66f957e',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart (Atlas)',
#                                                       'Kart',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4f3c5b85fd20eb090a7c7346d26b5c54',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart', 'Østmarka']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcd8ed2e94600ee724785fdd35dff0e81',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp263da88d4172823d00bb702e0c4f38ef',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart',
#                                                       'Oslo',
#                                                       'Kart (Atlas)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3e3743a64862741eec86187f6dbf5443',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Fredning',
#                                                       'Kart',
#                                                       'Kulturminner og '
#                                                       'kulturminnevern',
#                                                       'Oslo',
#                                                       'Arkitektur',
#                                                       'Arkitekturvern']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp791c20456f5897c7fc5cf3618c14bc63',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart',
#                                                       'Kart (Atlas)',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpa1caded2dc3f577b3005e096bf6173fa',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp899892e73232f9fe9136425e3597b203',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo', 'Aviser']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9076409787fda49b82ae9e469a0cdbd3',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart',
#                                                       'Oslo',
#                                                       'Kart (Atlas)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9e9b912ccbf3f623dcb23b8d1dae5369',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart', 'Nordmarka']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp56ba286ac0b48a65eac04b4af2aea734',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9a8ccf11fe88b91119c086d212dbd9dd',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Follo',
#                                                       'Drammen',
#                                                       'Romerike',
#                                                       'Oslo',
#                                                       'Kart']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpce0ffea4528538e3e205c7b4908f3f58',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Kart',
#                                                       'Historie',
#                                                       'Veier',
#                                                       'Norge']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp15dd28180512299d16bce20650683030',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Vestmarka', 'Kart']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpaf524b744033460e00077498b92446e8',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3a889c5272f323ec73288c4a01e4d95b',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpe7eb6bd2bdb5b6e5ff193e599d1236d0',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Historie', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp439d66c6b6cf2b17172f247e8d228131',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Norge',
#                                                       'Narkotikamisbruk',
#                                                       'Narkotikapolitikk']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpebd6fd43c388f20be234a4bcaa746a99',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo', 'Bysosiologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp24e239a63dfbc856e57f4bdfc4319ecf',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Middelalderen',
#                                                       '800-1536',
#                                                       'Fortidsminner',
#                                                       'Oslo',
#                                                       'Historie']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp723c4734e2f96d9be6ca48564170c8be',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Bysosiologi', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8e960f9c6a40954c9ff9942c304603fb',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Geografi og reiser']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp1b1471d62c198e15246227e9a13d47d0',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo-avtalen (1993)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpba09326bb044e3632e5256dff479c331',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo', 'Bysosiologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8b1fa9c61426a0a50b3a7ebc52f42843',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo Høyre']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp22b0cd41634c46459e0ac76beaf9eeaa',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpea975b2aac6dc7192e6919101e6857fc',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Akershus',
#                                                       'Drammen',
#                                                       'Kart']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpb4d957342cf828d33c61205e1d06c1ed',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp2f3e5207c8a4e84a5c1af79c945ecee9',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kart', 'Vestmarka']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp6d9b46a425aca0c461ba64b7863cd194',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Østmarka', 'Kart']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp95eab5740932220b9a89bb067535ef44',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kulturhistorie',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp14c85dd41efe8cd18b3302a71a7ebf7b',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpee7fb57fd5ac5ea07522413ec4e28919',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo', 'Bysosiologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp2eaf1ef50c73fce1a9081f5ab28ac8a2',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp025136678067',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo-avtalen (1993)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpfc6f210501fbb79c36ccb375ea9ff69d',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Terrorangrepene',
#                                                       'Høyreekstremisme',
#                                                       'Politisk retorikk']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8d77b442af5edc8ac6472aca5400e5a8',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       '1945-1999',
#                                                       'Historie',
#                                                       'Dagligliv',
#                                                       'Tøyen (Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp19a72e8bd118772c760eb7279f879413',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp79fd97fa34ea5a9c7291a37a7a6dc644',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpe51475fd93b66739bf052e1fe3d86e0b',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcfe2828e4941c17d52b5c3b67a66c354',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp896514072183',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Arkitektur',
#                                                       'Betong']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpbe5adca45426505df22c095a026ff3be',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp71b282ed556642cfb5fe81d85a90bcf3',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8759cc2112c89edd5f158643151c8a57',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['1900-1999',
#                                                       'Historie',
#                                                       'Oslo',
#                                                       'Dagligliv']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpd29c0716476f84aef39c39b9fb08231f',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Rådhuset (Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4df7203722cfca38c40536e9edc30940',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kunstnere',
#                                                       'Oslo',
#                                                       'Norge',
#                                                       'Kulturhistorie']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp554db1bec19d6a4b846c0941683654b6',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp5440c0395e940af18d2482ef10e080e0',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo', 'Bysosiologi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp2d57dd46bb50b923ea41b7592a78e784',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Kulturhistorie',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp81d507d025a61d60b955f4aed35a3c90',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Historie',
#                                                       'Dagligliv',
#                                                       '1900-1999']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf2669e4f0e8d815a0f0897629c632edf',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Arkitektur', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpa966f4a80e61cecc3b3d6a545de80c62',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp1b468e6e530fc8206763bdc042b772ee',
#                     '_index': 'publication',
#                     '_score': 8.766127,
#                     '_source': {'work': {'subjects': ['Dagligliv',
#                                                       'Oslo',
#                                                       'Historie',
# ...
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp16027bf84aee737b7a2caa432dde0ce0',
#                     '_index': 'publication',
#                     '_score': 6.7939134,
#                     '_source': {'work': {'subjects': ['Byplanlegging',
#                                                       'Områdeplanlegging',
#                                                       'Oslo',
#                                                       'Aker',
#                                                       'Byer',
#                                                       'Bærum']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp007b141d4b17980bccfc06b9f68e8aeb',
#                     '_index': 'publication',
#                     '_score': 6.7939134,
#                     '_source': {'work': {'subjects': ['Boligforhold', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4ac1a952e5522587a903941ee6374768',
#                     '_index': 'publication',
#                     '_score': 6.7793026,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp7eae2e5c1a2c4cb66d42edc4f706c063',
#                     '_index': 'publication',
#                     '_score': 6.737451,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp12af50ec783322d7d5b8f9a63ecf8e35',
#                     '_index': 'publication',
#                     '_score': 6.737451,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpccb422d854118e900e09165e5816962d',
#                     '_index': 'publication',
#                     '_score': 6.737451,
#                     '_source': {'work': {'subjects': ['Katter',
#                                                       'Dikt og sanger']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8cda53a757c6f464b3ecb59503842e53',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Oslo '
#                                                       'sanitetsforening']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8cf5893ab5c874f752403af27d3301df',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp92e8682e96d9b76521f95878f817d29f',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Læregutthjemmet '
#                                                       '(Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp962e1881f7f358c49aad60f1dca330bb',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Læregutthjemmet '
#                                                       '(Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp82592e0f2bed72a172185e7a12123162',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Broderi']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpa61c0a8582d0f18e1de97a86ea1481dd',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8169bf2b2548908f7305581d24daeb76',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8a027bc93432bf8b04bdee94e764158c',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Krigsskolen (Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp6ba1e280aaaa264181f85446a1633bea',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Oslo lærerinnelag']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpfb899c5f8a42dff0e9f7ec6951b2fa13',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3e872256758e155555acf2daaa2d9bda',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp40d050a08675c220a561969b4e23561c',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Trafikkregulering',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp50c212bc5d9faaed41481869a9abf798',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Rådhuset (Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp850ded3089ca43dcf6082d4bfc87f1ab',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Grünerløkka (Oslo)',
#                                                       'Oslo',
#                                                       'Byfornyelse']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp8a85b35c1141d619c5c0a76d4082a227',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Byer',
#                                                       'Parker',
#                                                       'Akerselva (Oslo)',
#                                                       'Byplanlegging',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9afe2fd83d179a63dc9a3f202a69691d',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Norge',
#                                                       'Glass',
#                                                       'Glassverk',
#                                                       'Christiania glasmagasin '
#                                                       '(Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp9b30a3ea337bd0d166ab596e23425513',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Byer',
#                                                       'Trafikkregulering',
#                                                       'Byplanlegging',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpa19389a36fd697a5c979cc2e780a81d7',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Byer',
#                                                       'Trafikkregulering',
#                                                       'Oslo',
#                                                       'Byplanlegging']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpc4d1bd187f606a077a73a741ccb9d070',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpcdc3a34ec2cae93ba1a4e74f8f0b4bc4',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Oslo',
#                                                       'Byfornyelse',
#                                                       'Sofienberg (Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpd8d9a2fe71f082544319680a5197ab90',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Oslo '
#                                                       'sjømannsforening']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpde04c22b572b695300ed6667a2d738b4',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Oslo '
#                                                       'sanitetsforening']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpbc756bf3ebd31dac557c55e4d7c5d722',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Kart', 'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3913088b638fab1339546252c84d632a',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Oslo tennisklub']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp824c17ecf56d85afaeeecc8ddc177fd1',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Biler']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp3016fe5f802594691f91844a9bff698e',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Malerkunst', 'Norge']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpaebb708e9dc6bc45606b7689ae5f3001',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Norge', 'Frimerker']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp23633cabfdabc1421ffab91f5238ed3e',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Veier',
#                                                       'Norge',
#                                                       'Kart',
#                                                       'Oslo']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp469d0010c1035a6bf77d9708a774e48c',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Kommuneplaner',
#                                                       'Arealplanlegging',
#                                                       'Oslo',
#                                                       'Forvaltning']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp4e3055d12c3d6bd3072e192e7eb7f893',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpf98accae4f2572eeb00c430097ed9dc3',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpc022c0543b293e6f75c28e55f88347ab',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Motiv',
#                                                       'Kunst',
#                                                       'Klær',
#                                                       'Mote',
#                                                       'Norge',
#                                                       'Kongelige',
#                                                       'Portretter']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpe8f1871eeb709016ab696e7d76d9637e',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Motzfeldt, Benny '
#                                                       '(glasskunstner)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fpec710bbbb9d959ec8b9eaa92b3e3c5e1',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Ekebergbanen (Oslo)']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp85f99fa9ecf3a1c2865652b158173317',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {'work': {'subjects': ['Forvaltning',
#                                                       'Oslo',
#                                                       'Kontroll av misligheter '
#                                                       'og korrupsjon']}},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp340820b40fe915893e8396e3f64fff71',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'},
#                    {'_id': 'http%3A%2F%2Fdata.deichman.no%2Fpublication%2Fp1bf7c47e1128a6e2e947c46d360bb745',
#                     '_index': 'publication',
#                     '_score': 6.7215676,
#                     '_source': {},
#                     '_type': '_doc'}],
#           'max_score': 13.095567,
#           'total': {'relation': 'eq', 'value': 7251}},
#  'timed_out': False,
#  'took': 131}
